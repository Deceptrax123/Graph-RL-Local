# %%
import pandas as pd 
import numpy as np

# %%
from dotenv import load_dotenv
import os 
load_dotenv('.env')

data=pd.read_csv(os.getenv('MARKERS'))

# %%
data
# Out:
#       Frame  Second          X1         Y1         Z1         X2         Y2  \
# 0         1     0.00  60.021797  1443.0741  311.86240  61.064270  1096.8744
# 1         2     0.01  60.069859  1443.1228  311.89890  61.097084  1096.9009
# 2         3     0.02  60.154324  1443.1433  311.92224  61.147366  1096.8954
# 3         4     0.03  60.207279  1443.1783  311.98526  61.167004  1096.8905
# 4         5     0.04  60.303699  1443.2056  312.00208  61.221062  1096.8752
# ...     ...      ...        ...        ...        ...        ...        ...
# 2441   2442    24.41  58.188293  1446.4814  822.78558  63.261845  1095.8350
# 2442   2443    24.42  58.215466  1446.4301  822.83960  64.636177  1095.7661
# 2443   2444    24.43  58.285892  1446.4529  822.91986  64.279175  1095.9078
# 2444   2445    24.44  58.300079  1446.4514  822.95374  64.238228  1095.8024
# 2445   2446    24.45  58.273842  1446.4392  822.99353  64.315094  1095.8285
#
# ...

# %%
data['X1']
# Out:
# 0       60.021797
# 1       60.069859
# 2       60.154324
# 3       60.207279
# 4       60.303699
#           ...
# 2441    58.188293
# 2442    58.215466
# 2443    58.285892
# 2444    58.300079
# 2445    58.273842
# Name: X1, Length: 2446, dtype: float64
